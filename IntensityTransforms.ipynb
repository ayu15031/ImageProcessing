# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("download.jpg")

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap="gray")

# %%
# image negative
img_gray= 255-img_gray

plt.imshow(img_gray, cmap="gray")

# %%
img = cv2.imread("log.tif")

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img, cmap="gray")

# %%
# Log transform

c = 255/(np.log(1 + np.max(img)))

img =img+1

img_log = c*np.log(img)

img_log = np.array(img_log, dtype = np.uint8)

# %%
plt.imshow(img_log, cmap='gray')

# %%
img = cv2.imread("gamma.tif")

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap="gray")

# %%
# Power Law Tranform with different gammas

c=1
gamma=0.05
gamma_corrected = 255*((img_gray/255)**gamma)

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])
    

gamma_corrected = np.array(gamma_corrected, dtype = np.uint8) 

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])

plt.imshow(gamma_corrected, cmap="gray")

# %%
gamma=0.2
gamma_corrected = 255*((img_gray/255)**gamma)

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])
    

gamma_corrected = np.array(gamma_corrected, dtype = np.uint8) 

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])
# # img = np.array(img, dtype = np.uint8) 


plt.imshow(gamma_corrected, cmap="gray")

# %%
gamma=0.9
gamma_corrected = 255*((img_gray/255)**gamma)

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])
    

gamma_corrected = np.array(gamma_corrected, dtype = np.uint8) 
# img = np.array(img, dtype = np.uint8) 


plt.imshow(gamma_corrected, cmap="gray")

# %%
gamma=2.0
gamma_corrected = 255*((img_gray/255)**gamma)

# for i in range(gamma_corrected.shape[0]):
#     print(gamma_corrected[6][i])
    

gamma_corrected = np.array(gamma_corrected, dtype = np.uint8) 

# img = np.array(img, dtype = np.uint8) 


plt.imshow(gamma_corrected, cmap="gray")
